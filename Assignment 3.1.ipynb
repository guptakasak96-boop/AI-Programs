# %%
# !pip install opencv.python

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
img = cv2.imread("abc.jpeg")
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
print(img.shape,50,60)
# Out:
# (1316, 2210, 3) 50 60

# %%
cv2.imshow("abc.jpeg",img)
cv2.waitKey(0)
# Out:
# -1

# %%
img_flip=cv2.flip(img,0)
cv2.imshow("abc.jpeg",img_flip)
cv2.waitKey(0)
# Out:
# -1
