# %%
# import random
numbers = [random.randint(10,60) for i in range (10)]

print("Random Numbers:", numbers)
print("Even Numbers:")
for num in numbers:
    if num % 2 == 0:
        print(num)
# Out:
# Random Numbers: [14, 52, 51, 10, 34, 35, 47, 44, 48, 11]
# Even Numbers:
# 14
# 52
# 10
# 34
# 44
# 48

# %%
text = "Plants is the soul of Earth"
print("Quote:",text)
reverse_string = text[::-1]
print("Reverse Quote:", reverse_string)

reverse_words = " ".join(text.split()[::-1])
print("Reverse Words In Quote:", reverse_words)
# Out:
# Quote: Plants is the soul of Earth
# Reverse Quote: htraE fo luos eht si stnalP
# Reverse Words In Quote: Earth of soul the is Plants
